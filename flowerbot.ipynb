# %%
import time
import random
import asyncio
from telegram import Update, InlineKeyboardButton, InlineKeyboardMarkup, ReplyKeyboardMarkup
from telegram.ext import (
    Application,
    ApplicationBuilder,
    CommandHandler,
    MessageHandler,
    ContextTypes,
    filters,
)

# %%
import logging
logging.basicConfig(level=logging.DEBUG)

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
# информация о цветах: типы и стадии роста
FLOWER_TYPES = ["Цветок1", "Цветок2", "Цветок3"]
GROWTH_STAGES = ["Семечко", "Росточек", "Маленький стебелёк", "Большой стебелёк", "Цветочек"]

# кнопки для интерфейса
MAIN_MENU = [
    ["Полить 💧", "Удобрить 🌱"],  # кнопки для поливки и удобрения
    ["Инвентарь 🏷️", "Новый цветочек🌺"],  # кнопки для инвентаря и добавления цветочка
]

# частота возможности полива и удобрения
WATER_COOLDOWN = 3 * 60 * 60  # 3 часа в секундах
FERTILIZE_COOLDOWN = 12 * 60 * 60  # 12 часов в секундах

# %%
class Flower:
    def __init__(self, flower_type):
        self.type = flower_type # тип цветка
        self.stage = 0 # стадия роста
        self.water_count = 0 # кол-во поливов
        self.fertilize_count = 0 # кол-во удобрения
        self.last_watered = 0 # время полива
        self.last_fertilized = 0 # время удобрения
        self.notified_water = False  # флаг для уведомления о поливке
        self.notified_fertilize = False  # флаг для уведомления об удобрении

    def get_image_path(self): # получение изображений
        return f"images/{self.type.lower()}_{self.stage}.png"
    
    def can_water(self): # возможность полива
        return time.time() - self.last_watered >= WATER_COOLDOWN

    def can_fertilize(self): # возможность удобрения
        return time.time() - self.last_fertilized >= FERTILIZE_COOLDOWN

    def water(self): # полив
        if self.can_water():
            self.water_count += 1
            self.last_watered = time.time()
            self.notified_water = False  # сбрасываем флаг уведомления после действия
            return True
        return False

    def fertilize(self): # удобрение
        if self.can_fertilize():
            self.fertilize_count += 1
            self.last_fertilized = time.time()
            self.notified_fertilize = False  # Сбрасываем флаг уведомления после действия
            return True
        return False

    def time_until_water(self): # время до возможности следующего полива
        return max(0, WATER_COOLDOWN - (time.time() - self.last_watered))

    def time_until_fertilize(self): # время до возможности следующего удобрения
        return max(0, FERTILIZE_COOLDOWN - (time.time() - self.last_fertilized))

    def check_growth(self): # проверка роста
        growth_requirements = [ # требования кол-ва поливов и удобрения 
            (1, 1),  # семечко -> росточек
            (5, 2),  # росточек -> маленький стебелёк
            (9, 3),  # маленький стебелёк -> большой стебелёк
            (5, 2),  # большой стебелёк -> цветочек
        ]
        # переход на следующую стадию роста
        if self.stage < len(growth_requirements): 
            water_req, fert_req = growth_requirements[self.stage]
            if self.water_count >= water_req and self.fertilize_count >= fert_req:
                self.stage += 1
                self.water_count = 0
                self.fertilize_count = 0
                return True
        return False

# %%
class User:
    def __init__(self, chat_id):
        self.chat_id = chat_id # айди чата с пользователем
        self.flowers = [] # цветы конкретного пользователя
        self.add_flower() # добавить цветок

    def add_flower(self):
        new_flower = Flower(random.choice(FLOWER_TYPES)) # рандомно выбираем цветок
        self.flowers.append(new_flower) # добавляем к пользователю
        return new_flower

# %%
# информация о пользователях
users = {}

# %%
def get_user(user_id, chat_id=None):
    if user_id not in users:
        users[user_id] = User(chat_id)
    return users[user_id]

# %%
# обработка команды /start
async def start(update: Update, context: ContextTypes.DEFAULT_TYPE):
    user = get_user(update.effective_user.id, update.effective_chat.id)
    keyboard = ReplyKeyboardMarkup([["/start"]], resize_keyboard=True)
    await update.message.reply_text(
        "Добро пожаловать в твой собственный мини-сад! 🌸\n\n"
        "Для начала ты получаешь один цветочек в подарок! 🎀\n\n"
        "Используй кнопки ниже, чтобы ухаживать за своим цветочком!",
        reply_markup=keyboard,
    )
    await show_inventory(update, context)

# команда полива цветка
async def water(update: Update, context: ContextTypes.DEFAULT_TYPE):
    user = get_user(update.effective_user.id)
    current_flower = user.flowers[-1] # уточняем, что полить нужно именно последний цветок
    if current_flower.water():
        if current_flower.check_growth():
            await update.message.reply_photo( # если цветок перешел на новую стадию - показываем это пользователю
                photo=open(current_flower.get_image_path(), 'rb'),
                caption=f"Ура!🎉 Твой {current_flower.type} достиг стадии: {GROWTH_STAGES[current_flower.stage]}! 🌸",
                reply_markup=ReplyKeyboardMarkup(MAIN_MENU, resize_keyboard=True),
            )
        else:
            await update.message.reply_text(
                "Цветочек полит! 💧",
                reply_markup=ReplyKeyboardMarkup(MAIN_MENU, resize_keyboard=True),
            )
    else:
        time_left = current_flower.time_until_water() 
        hours, minutes = divmod(int(time_left // 60), 60)
        await update.message.reply_text(
            f"Нужно немного подождать, чтобы снова полить! ⏳\nПопробуй снова через {hours} часов {minutes} минут.",
            reply_markup=ReplyKeyboardMarkup(MAIN_MENU, resize_keyboard=True),
        )

async def fertilize(update: Update, context: ContextTypes.DEFAULT_TYPE):
    user = get_user(update.effective_user.id)
    current_flower = user.flowers[-1] # уточняем, что удобрить нужно именно последний цветок
    if current_flower.fertilize():
        if current_flower.check_growth():
            await update.message.reply_photo( # если цветок перешел на новую стадию - показываем это пользователю
                photo=open(current_flower.get_image_path(), 'rb'),
                caption=f"Ура!🎉 Твой {current_flower.type} достиг стадии: {GROWTH_STAGES[current_flower.stage]}! 🌸",
                reply_markup=ReplyKeyboardMarkup(MAIN_MENU, resize_keyboard=True),
            )
        else:
            await update.message.reply_text(
                "Цветочек удобрен! 🌱",
                reply_markup=ReplyKeyboardMarkup(MAIN_MENU, resize_keyboard=True),
            )
    else:
        time_left = current_flower.time_until_fertilize()
        hours, minutes = divmod(int(time_left // 60), 60)
        await update.message.reply_text(
            f"Нужно немного подождать, чтобы снова удобрить! ⏳\nПопробуй снова через {hours} часов {minutes} минут.",
            reply_markup=ReplyKeyboardMarkup(MAIN_MENU, resize_keyboard=True),
        )

# команда отображения инвентаря
async def show_inventory(update: Update, context: ContextTypes.DEFAULT_TYPE):
    user = get_user(update.effective_user.id)
    inventory = "Твои цветочки:\n\n"
    for i, flower in enumerate(user.flowers):
        inventory += f"{i + 1}. {flower.type} - {GROWTH_STAGES[flower.stage]}\n"
    await update.message.reply_text(
        inventory,
        reply_markup=ReplyKeyboardMarkup(MAIN_MENU, resize_keyboard=True),
    )
    current_flower = user.flowers[-1]
    await update.message.reply_photo( # показываем только последний цветок
        photo=open(current_flower.get_image_path(), 'rb'),
        caption=f"Текущий цветок: {current_flower.type}, Стадия: {GROWTH_STAGES[current_flower.stage]}"
    )

# добавление нового цветка
async def add_new_flower(update: Update, context: ContextTypes.DEFAULT_TYPE):
    user = get_user(update.effective_user.id)
    if user.flowers[-1].stage == len(GROWTH_STAGES) - 1:  # если текущий цветок полностью вырос
        new_flower = user.add_flower()
        await update.message.reply_text( # когда цветок вырос, даем пользователю новый
            f"Позравляем! Твой цветок полностью вырос. Ты получаешь {new_flower.type}! 🌸",
            reply_markup=ReplyKeyboardMarkup(MAIN_MENU, resize_keyboard=True),
        )
    else:
        await update.message.reply_text(
            "Сначала нужно полностью выростить этот цветочек! 🌱",
            reply_markup=ReplyKeyboardMarkup(MAIN_MENU, resize_keyboard=True),
        )

# напоминания о поливе и удобрении
async def reminders(context: ContextTypes.DEFAULT_TYPE):
    for user_id, user in users.items():
        current_flower = user.flowers[-1]
        chat_id = user.chat_id

        if current_flower.can_water() and not current_flower.notified_water:
            await context.bot.send_message(chat_id=chat_id, text="Кажется, цветочек уже можно полить!;)")
            current_flower.notified_water = True
        if current_flower.can_fertilize() and not current_flower.notified_fertilize:
            await context.bot.send_message(chat_id=chat_id, text="Кажется, цветочек уже можно удобрить!;)")
            current_flower.notified_fertilize = True

# обработка текста кнопок и связь с командами
async def handle_text(update: Update, context: ContextTypes.DEFAULT_TYPE):
    user_text = update.message.text

    if user_text == "Полить 💧":
        await water(update, context)
    elif user_text == "Удобрить 🌱":
        await fertilize(update, context)
    elif user_text == "Инвентарь 🏷️":
        await show_inventory(update, context)
    elif user_text == "Новый цветочек🌺":
        await add_new_flower(update, context)
    else:
        await update.message.reply_text("Я не понимаю эту команду. Попробуйте снова!")

# %%
async def main():
    # создаем приложение
    TOKEN = "your_token_here"
    application = ApplicationBuilder().token(TOKEN).build()

    # регистрируем обработчики команд
    application.add_handler(CommandHandler("start", start))
    application.add_handler(MessageHandler(filters.TEXT & ~filters.COMMAND, handle_text))

    # постоянно проверяем наличие напоминаний
    application.job_queue.run_repeating(reminders, interval=60, first=10)

    try:
        await application.initialize()
    except Exception as e:
        print(f"Error initializing bot: {e}")

    # здесь была попытка корректно отработать завершение работы бота, но оно, к сожалению, в итоге так и не заработало корректно в Jupyter
    try:
        print("Бот запущен. Нажмите Ctrl+C для остановки.")
        await application.run_polling()
    except KeyboardInterrupt:
        print("Остановка бота...")
    finally:
        # корректное завершение
        await application.shutdown()
        print("Бот остановлен.")

# %%
if __name__ == "__main__":
    asyncio.run(main())
# Out:
# INFO:apscheduler.scheduler:Adding job tentatively -- it will be properly scheduled when the scheduler starts
# DEBUG:telegram.ext.ExtBot:Calling Bot API endpoint `getMe` with parameters `{}`
# DEBUG:httpcore.connection:connect_tcp.started host='api.telegram.org' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x000001BC39B302F0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x000001BC3C0A7AD0> server_hostname='api.telegram.org' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x000001BC39B30C20>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'nginx/1.18.0'), (b'Date', b'Thu, 16 Jan 2025 19:24:53 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'251'), (b'Connection', b'keep-alive'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Methods', b'GET, POST, OPTIONS'), (b'Access-Control-Expose-Headers', b'Content-Length,Content-Type,Date,Server,Connection')])
# INFO:httpx:HTTP Request: POST https://api.telegram.org/bot8034672081:AAF6O5a2wS1HSV5dVzDn2UeQuKbHL2kXGcM/getMe "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:telegram.ext.ExtBot:Call to Bot API endpoint `getMe` finished with return value `{'id': 8034672081, 'is_bot': True, 'first_name': 'flower bot', 'username': 'haruhanabot', 'can_join_groups': True, 'can_read_all_group_messages': False, 'supports_inline_queries': False, 'can_connect_to_business': False, 'has_main_web_app': False}`
# DEBUG:telegram.ext.ExtBot:This Bot is already initialized.
# DEBUG:telegram.ext.Application:This Application is already initialized.
# DEBUG:telegram.ext.Updater:Updater started (polling)
# DEBUG:telegram.ext.Updater:Start network loop retry bootstrap del webhook
# DEBUG:telegram.ext.Updater:Deleting webhook
# DEBUG:telegram.ext.ExtBot:Calling Bot API endpoint `deleteWebhook` with parameters `{}`
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'nginx/1.18.0'), (b'Date', b'Thu, 16 Jan 2025 19:24:53 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'68'), (b'Connection', b'keep-alive'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Methods', b'GET, POST, OPTIONS'), (b'Access-Control-Expose-Headers', b'Content-Length,Content-Type,Date,Server,Connection')])
# INFO:httpx:HTTP Request: POST https://api.telegram.org/bot8034672081:AAF6O5a2wS1HSV5dVzDn2UeQuKbHL2kXGcM/deleteWebhook "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:telegram.ext.ExtBot:Call to Bot API endpoint `deleteWebhook` finished with return value `True`
# DEBUG:telegram.ext.Updater:Bootstrap done
# DEBUG:telegram.ext.Updater:Waiting for polling to start
# DEBUG:telegram.ext.Updater:Polling updates from Telegram started
# DEBUG:telegram.ext.Updater:Start network loop retry getting Updates
# INFO:apscheduler.scheduler:Added job "reminders" to job store "default"
# INFO:apscheduler.scheduler:Scheduler started
# DEBUG:telegram.ext.Application:JobQueue started
# INFO:telegram.ext.Application:Application started
# DEBUG:telegram.ext.ExtBot:Calling Bot API endpoint `getUpdates` with parameters `{'timeout': 10, 'offset': 0}`
# DEBUG:apscheduler.scheduler:Looking for jobs to run
# DEBUG:apscheduler.scheduler:Next wakeup is due at 2025-01-16 19:25:03.255858+00:00 (in 9.439854 seconds)
# DEBUG:httpcore.connection:connect_tcp.started host='api.telegram.org' port=443 local_address=None timeout=5.0 socket_options=None
# Бот запущен. Нажмите Ctrl+C для остановки.
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x000001BC3C09F620>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x000001BC3C0A7A50> server_hostname='api.telegram.org' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x000001BC3C117CE0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:apscheduler.scheduler:Looking for jobs to run
# DEBUG:apscheduler.scheduler:Next wakeup is due at 2025-01-16 19:26:03.255858+00:00 (in 59.988993 seconds)
# INFO:apscheduler.executors.default:Running job "reminders (trigger: interval[0:01:00], next run at: 2025-01-16 19:26:03 UTC)" (scheduled at 2025-01-16 19:25:03.255858+00:00)
# INFO:apscheduler.executors.default:Job "reminders (trigger: interval[0:01:00], next run at: 2025-01-16 19:26:03 UTC)" executed successfully
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'nginx/1.18.0'), (b'Date', b'Thu, 16 Jan 2025 19:25:04 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'23'), (b'Connection', b'keep-alive'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Methods', b'GET, POST, OPTIONS'), (b'Access-Control-Expose-Headers', b'Content-Length,Content-Type,Date,Server,Connection')])
# INFO:httpx:HTTP Request: POST https://api.telegram.org/bot8034672081:AAF6O5a2wS1HSV5dVzDn2UeQuKbHL2kXGcM/getUpdates "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:telegram.ext.ExtBot:Call to Bot API endpoint `getUpdates` finished with return value `[]`
# DEBUG:telegram.ext.ExtBot:No new updates found.
# DEBUG:telegram.ext.ExtBot:Calling Bot API endpoint `getUpdates` with parameters `{'timeout': 10, 'offset': 0}`
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'nginx/1.18.0'), (b'Date', b'Thu, 16 Jan 2025 19:25:14 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'23'), (b'Connection', b'keep-alive'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Methods', b'GET, POST, OPTIONS'), (b'Access-Control-Expose-Headers', b'Content-Length,Content-Type,Date,Server,Connection')])
# INFO:httpx:HTTP Request: POST https://api.telegram.org/bot8034672081:AAF6O5a2wS1HSV5dVzDn2UeQuKbHL2kXGcM/getUpdates "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:telegram.ext.ExtBot:Call to Bot API endpoint `getUpdates` finished with return value `[]`
# DEBUG:telegram.ext.ExtBot:No new updates found.
# DEBUG:telegram.ext.ExtBot:Calling Bot API endpoint `getUpdates` with parameters `{'timeout': 10, 'offset': 0}`
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'nginx/1.18.0'), (b'Date', b'Thu, 16 Jan 2025 19:25:24 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'23'), (b'Connection', b'keep-alive'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Methods', b'GET, POST, OPTIONS'), (b'Access-Control-Expose-Headers', b'Content-Length,Content-Type,Date,Server,Connection')])
# INFO:httpx:HTTP Request: POST https://api.telegram.org/bot8034672081:AAF6O5a2wS1HSV5dVzDn2UeQuKbHL2kXGcM/getUpdates "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:telegram.ext.ExtBot:Call to Bot API endpoint `getUpdates` finished with return value `[]`
# DEBUG:telegram.ext.ExtBot:No new updates found.
# DEBUG:telegram.ext.ExtBot:Calling Bot API endpoint `getUpdates` with parameters `{'timeout': 10, 'offset': 0}`
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'nginx/1.18.0'), (b'Date', b'Thu, 16 Jan 2025 19:25:34 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'23'), (b'Connection', b'keep-alive'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Methods', b'GET, POST, OPTIONS'), (b'Access-Control-Expose-Headers', b'Content-Length,Content-Type,Date,Server,Connection')])
# INFO:httpx:HTTP Request: POST https://api.telegram.org/bot8034672081:AAF6O5a2wS1HSV5dVzDn2UeQuKbHL2kXGcM/getUpdates "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:telegram.ext.ExtBot:Call to Bot API endpoint `getUpdates` finished with return value `[]`
# DEBUG:telegram.ext.ExtBot:No new updates found.
# DEBUG:telegram.ext.ExtBot:Calling Bot API endpoint `getUpdates` with parameters `{'timeout': 10, 'offset': 0}`
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'nginx/1.18.0'), (b'Date', b'Thu, 16 Jan 2025 19:25:44 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'23'), (b'Connection', b'keep-alive'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Methods', b'GET, POST, OPTIONS'), (b'Access-Control-Expose-Headers', b'Content-Length,Content-Type,Date,Server,Connection')])
# INFO:httpx:HTTP Request: POST https://api.telegram.org/bot8034672081:AAF6O5a2wS1HSV5dVzDn2UeQuKbHL2kXGcM/getUpdates "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:telegram.ext.ExtBot:Call to Bot API endpoint `getUpdates` finished with return value `[]`
# DEBUG:telegram.ext.ExtBot:No new updates found.
# DEBUG:telegram.ext.ExtBot:Calling Bot API endpoint `getUpdates` with parameters `{'timeout': 10, 'offset': 0}`
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'nginx/1.18.0'), (b'Date', b'Thu, 16 Jan 2025 19:25:54 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'23'), (b'Connection', b'keep-alive'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Methods', b'GET, POST, OPTIONS'), (b'Access-Control-Expose-Headers', b'Content-Length,Content-Type,Date,Server,Connection')])
# INFO:httpx:HTTP Request: POST https://api.telegram.org/bot8034672081:AAF6O5a2wS1HSV5dVzDn2UeQuKbHL2kXGcM/getUpdates "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:telegram.ext.ExtBot:Call to Bot API endpoint `getUpdates` finished with return value `[]`
# DEBUG:telegram.ext.ExtBot:No new updates found.
# DEBUG:telegram.ext.ExtBot:Calling Bot API endpoint `getUpdates` with parameters `{'timeout': 10, 'offset': 0}`
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'nginx/1.18.0'), (b'Date', b'Thu, 16 Jan 2025 19:25:54 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'365'), (b'Connection', b'keep-alive'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Methods', b'GET, POST, OPTIONS'), (b'Access-Control-Expose-Headers', b'Content-Length,Content-Type,Date,Server,Connection')])
# INFO:httpx:HTTP Request: POST https://api.telegram.org/bot8034672081:AAF6O5a2wS1HSV5dVzDn2UeQuKbHL2kXGcM/getUpdates "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:telegram.ext.ExtBot:Call to Bot API endpoint `getUpdates` finished with return value `[{'update_id': 390207012, 'message': {'message_id': 498, 'from': {'id': 740990236, 'is_bot': False, 'first_name': 'moonsheep', 'username': 'moonsheep', 'language_code': 'ru'}, 'chat': {'id': 740990236, 'first_name': 'moonsheep', 'username': 'moonsheep', 'type': 'private'}, 'date': 1737055554, 'text': '/start', 'entities': [{'offset': 0, 'length': 6, 'type': 'bot_command'}]}}]`
# DEBUG:telegram.ext.ExtBot:Getting updates: [390207012]
# DEBUG:telegram.ext.Application:Processing update Update(message=Message(channel_chat_created=False, chat=Chat(first_name='moonsheep', id=740990236, type=<ChatType.PRIVATE>, username='moonsheep'), date=datetime.datetime(2025, 1, 16, 19, 25, 54, tzinfo=datetime.timezone.utc), delete_chat_photo=False, entities=(MessageEntity(length=6, offset=0, type=<MessageEntityType.BOT_COMMAND>),), from_user=User(first_name='moonsheep', id=740990236, is_bot=False, language_code='ru', username='moonsheep'), group_chat_created=False, message_id=498, supergroup_chat_created=False, text='/start'), update_id=390207012)
# DEBUG:telegram.ext.ExtBot:Calling Bot API endpoint `sendMessage` with parameters `{'chat_id': 740990236, 'text': 'Добро пожаловать в твой собственный мини-сад! 🌸\n\nДля начала ты получаешь один цветочек в подарок! 🎀\n\nИспользуй кнопки ниже, чтобы ухаживать за своим цветочком!', 'reply_markup': ReplyKeyboardMarkup(keyboard=((KeyboardButton(text='/start'),),), resize_keyboard=True)}`
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.complete
# DEBUG:telegram.ext.ExtBot:Calling Bot API endpoint `getUpdates` with parameters `{'timeout': 10, 'offset': 390207013}`
# DEBUG:httpcore.connection:connect_tcp.started host='api.telegram.org' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x000001BC38AC9160>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x000001BC3C0A7AD0> server_hostname='api.telegram.org' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x000001BC3BBBB1D0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'nginx/1.18.0'), (b'Date', b'Thu, 16 Jan 2025 19:25:55 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'1066'), (b'Connection', b'keep-alive'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Methods', b'GET, POST, OPTIONS'), (b'Access-Control-Expose-Headers', b'Content-Length,Content-Type,Date,Server,Connection')])
# INFO:httpx:HTTP Request: POST https://api.telegram.org/bot8034672081:AAF6O5a2wS1HSV5dVzDn2UeQuKbHL2kXGcM/sendMessage "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:telegram.ext.ExtBot:Call to Bot API endpoint `sendMessage` finished with return value `{'message_id': 499, 'from': {'id': 8034672081, 'is_bot': True, 'first_name': 'flower bot', 'username': 'haruhanabot'}, 'chat': {'id': 740990236, 'first_name': 'moonsheep', 'username': 'moonsheep', 'type': 'private'}, 'date': 1737055555, 'text': 'Добро пожаловать в твой собственный мини-сад! 🌸\n\nДля начала ты получаешь один цветочек в подарок! 🎀\n\nИспользуй кнопки ниже, чтобы ухаживать за своим цветочком!'}`
# DEBUG:telegram.ext.ExtBot:Calling Bot API endpoint `sendMessage` with parameters `{'chat_id': 740990236, 'text': 'Твои цветочки:\n\n1. Цветок2 - Семечко\n', 'reply_markup': ReplyKeyboardMarkup(keyboard=((KeyboardButton(text='Полить 💧'), KeyboardButton(text='Удобрить 🌱')), (KeyboardButton(text='Инвентарь 🏷️'), KeyboardButton(text='Новый цветочек🌺'))), resize_keyboard=True)}`
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'nginx/1.18.0'), (b'Date', b'Thu, 16 Jan 2025 19:25:55 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'409'), (b'Connection', b'keep-alive'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Methods', b'GET, POST, OPTIONS'), (b'Access-Control-Expose-Headers', b'Content-Length,Content-Type,Date,Server,Connection')])
# INFO:httpx:HTTP Request: POST https://api.telegram.org/bot8034672081:AAF6O5a2wS1HSV5dVzDn2UeQuKbHL2kXGcM/sendMessage "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:telegram.ext.ExtBot:Call to Bot API endpoint `sendMessage` finished with return value `{'message_id': 500, 'from': {'id': 8034672081, 'is_bot': True, 'first_name': 'flower bot', 'username': 'haruhanabot'}, 'chat': {'id': 740990236, 'first_name': 'moonsheep', 'username': 'moonsheep', 'type': 'private'}, 'date': 1737055555, 'text': 'Твои цветочки:\n\n1. Цветок2 - Семечко'}`
# DEBUG:telegram.ext.ExtBot:Calling Bot API endpoint `sendPhoto` with parameters `{'chat_id': 740990236, 'photo': <telegram._files.inputfile.InputFile object at 0x000001BC39CDB0C0>, 'caption': 'Текущий цветок: Цветок2, Стадия: Семечко'}`
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'nginx/1.18.0'), (b'Date', b'Thu, 16 Jan 2025 19:25:55 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'1343'), (b'Connection', b'keep-alive'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Methods', b'GET, POST, OPTIONS'), (b'Access-Control-Expose-Headers', b'Content-Length,Content-Type,Date,Server,Connection')])
# INFO:httpx:HTTP Request: POST https://api.telegram.org/bot8034672081:AAF6O5a2wS1HSV5dVzDn2UeQuKbHL2kXGcM/sendPhoto "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:telegram.ext.ExtBot:Call to Bot API endpoint `sendPhoto` finished with return value `{'message_id': 501, 'from': {'id': 8034672081, 'is_bot': True, 'first_name': 'flower bot', 'username': 'haruhanabot'}, 'chat': {'id': 740990236, 'first_name': 'moonsheep', 'username': 'moonsheep', 'type': 'private'}, 'date': 1737055555, 'photo': [{'file_id': 'AgACAgIAAxkDAAIBkmeJTtbmU9dGIdjiEAo9fDMuD9asAAIr7DEbqPZISH6GCMHKFuHCAQADAgADcwADNgQ', 'file_unique_id': 'AQADK-wxG6j2SEh4', 'file_size': 716, 'width': 90, 'height': 90}, {'file_id': 'AgACAgIAAxkDAAIBkmeJTtbmU9dGIdjiEAo9fDMuD9asAAIr7DEbqPZISH6GCMHKFuHCAQADAgADbQADNgQ', 'file_unique_id': 'AQADK-wxG6j2SEhy', 'file_size': 4163, 'width': 320, 'height': 320}, {'file_id': 'AgACAgIAAxkDAAIBkmeJTtbmU9dGIdjiEAo9fDMuD9asAAIr7DEbqPZISH6GCMHKFuHCAQADAgADeAADNgQ', 'file_unique_id': 'AQADK-wxG6j2SEh9', 'file_size': 13681, 'width': 800, 'height': 800}, {'file_id': 'AgACAgIAAxkDAAIBkmeJTtbmU9dGIdjiEAo9fDMuD9asAAIr7DEbqPZISH6GCMHKFuHCAQADAgADeQADNgQ', 'file_unique_id': 'AQADK-wxG6j2SEh-', 'file_size': 25428, 'width': 1280, 'height': 1280}, {'file_id': 'AgACAgIAAxkDAAIBkmeJTtbmU9dGIdjiEAo9fDMuD9asAAIr7DEbqPZISH6GCMHKFuHCAQADAgADdwADNgQ', 'file_unique_id': 'AQADK-wxG6j2SEh8', 'file_size': 49482, 'width': 2048, 'height': 2048}], 'caption': 'Текущий цветок: Цветок2, Стадия: Семечко'}`
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'nginx/1.18.0'), (b'Date', b'Thu, 16 Jan 2025 19:25:59 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'350'), (b'Connection', b'keep-alive'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Methods', b'GET, POST, OPTIONS'), (b'Access-Control-Expose-Headers', b'Content-Length,Content-Type,Date,Server,Connection')])
# INFO:httpx:HTTP Request: POST https://api.telegram.org/bot8034672081:AAF6O5a2wS1HSV5dVzDn2UeQuKbHL2kXGcM/getUpdates "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:telegram.ext.ExtBot:Call to Bot API endpoint `getUpdates` finished with return value `[{'update_id': 390207013, 'message': {'message_id': 502, 'from': {'id': 740990236, 'is_bot': False, 'first_name': 'moonsheep', 'username': 'moonsheep', 'language_code': 'ru'}, 'chat': {'id': 740990236, 'first_name': 'moonsheep', 'username': 'moonsheep', 'type': 'private'}, 'date': 1737055559, 'text': 'Полить 💧'}}]`
# DEBUG:telegram.ext.ExtBot:Getting updates: [390207013]
# DEBUG:telegram.ext.Application:Processing update Update(message=Message(channel_chat_created=False, chat=Chat(first_name='moonsheep', id=740990236, type=<ChatType.PRIVATE>, username='moonsheep'), date=datetime.datetime(2025, 1, 16, 19, 25, 59, tzinfo=datetime.timezone.utc), delete_chat_photo=False, from_user=User(first_name='moonsheep', id=740990236, is_bot=False, language_code='ru', username='moonsheep'), group_chat_created=False, message_id=502, supergroup_chat_created=False, text='Полить 💧'), update_id=390207013)
# DEBUG:telegram.ext.ExtBot:Calling Bot API endpoint `sendMessage` with parameters `{'chat_id': 740990236, 'text': 'Цветочек полит! 💧', 'reply_markup': ReplyKeyboardMarkup(keyboard=((KeyboardButton(text='Полить 💧'), KeyboardButton(text='Удобрить 🌱')), (KeyboardButton(text='Инвентарь 🏷️'), KeyboardButton(text='Новый цветочек🌺'))), resize_keyboard=True)}`
# DEBUG:telegram.ext.ExtBot:Calling Bot API endpoint `getUpdates` with parameters `{'timeout': 10, 'offset': 390207014}`
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'nginx/1.18.0'), (b'Date', b'Thu, 16 Jan 2025 19:25:59 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'339'), (b'Connection', b'keep-alive'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Methods', b'GET, POST, OPTIONS'), (b'Access-Control-Expose-Headers', b'Content-Length,Content-Type,Date,Server,Connection')])
# INFO:httpx:HTTP Request: POST https://api.telegram.org/bot8034672081:AAF6O5a2wS1HSV5dVzDn2UeQuKbHL2kXGcM/sendMessage "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:telegram.ext.ExtBot:Call to Bot API endpoint `sendMessage` finished with return value `{'message_id': 503, 'from': {'id': 8034672081, 'is_bot': True, 'first_name': 'flower bot', 'username': 'haruhanabot'}, 'chat': {'id': 740990236, 'first_name': 'moonsheep', 'username': 'moonsheep', 'type': 'private'}, 'date': 1737055559, 'text': 'Цветочек полит! 💧'}`
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'nginx/1.18.0'), (b'Date', b'Thu, 16 Jan 2025 19:26:00 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'350'), (b'Connection', b'keep-alive'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Methods', b'GET, POST, OPTIONS'), (b'Access-Control-Expose-Headers', b'Content-Length,Content-Type,Date,Server,Connection')])
# INFO:httpx:HTTP Request: POST https://api.telegram.org/bot8034672081:AAF6O5a2wS1HSV5dVzDn2UeQuKbHL2kXGcM/getUpdates "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:telegram.ext.ExtBot:Call to Bot API endpoint `getUpdates` finished with return value `[{'update_id': 390207014, 'message': {'message_id': 504, 'from': {'id': 740990236, 'is_bot': False, 'first_name': 'moonsheep', 'username': 'moonsheep', 'language_code': 'ru'}, 'chat': {'id': 740990236, 'first_name': 'moonsheep', 'username': 'moonsheep', 'type': 'private'}, 'date': 1737055560, 'text': 'Полить 💧'}}]`
# DEBUG:telegram.ext.ExtBot:Getting updates: [390207014]
# DEBUG:telegram.ext.Application:Processing update Update(message=Message(channel_chat_created=False, chat=Chat(first_name='moonsheep', id=740990236, type=<ChatType.PRIVATE>, username='moonsheep'), date=datetime.datetime(2025, 1, 16, 19, 26, tzinfo=datetime.timezone.utc), delete_chat_photo=False, from_user=User(first_name='moonsheep', id=740990236, is_bot=False, language_code='ru', username='moonsheep'), group_chat_created=False, message_id=504, supergroup_chat_created=False, text='Полить 💧'), update_id=390207014)
# DEBUG:telegram.ext.ExtBot:Calling Bot API endpoint `sendMessage` with parameters `{'chat_id': 740990236, 'text': 'Цветочек полит! 💧', 'reply_markup': ReplyKeyboardMarkup(keyboard=((KeyboardButton(text='Полить 💧'), KeyboardButton(text='Удобрить 🌱')), (KeyboardButton(text='Инвентарь 🏷️'), KeyboardButton(text='Новый цветочек🌺'))), resize_keyboard=True)}`
# DEBUG:telegram.ext.ExtBot:Calling Bot API endpoint `getUpdates` with parameters `{'timeout': 10, 'offset': 390207015}`
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'nginx/1.18.0'), (b'Date', b'Thu, 16 Jan 2025 19:26:00 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'339'), (b'Connection', b'keep-alive'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Methods', b'GET, POST, OPTIONS'), (b'Access-Control-Expose-Headers', b'Content-Length,Content-Type,Date,Server,Connection')])
# INFO:httpx:HTTP Request: POST https://api.telegram.org/bot8034672081:AAF6O5a2wS1HSV5dVzDn2UeQuKbHL2kXGcM/sendMessage "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:telegram.ext.ExtBot:Call to Bot API endpoint `sendMessage` finished with return value `{'message_id': 505, 'from': {'id': 8034672081, 'is_bot': True, 'first_name': 'flower bot', 'username': 'haruhanabot'}, 'chat': {'id': 740990236, 'first_name': 'moonsheep', 'username': 'moonsheep', 'type': 'private'}, 'date': 1737055560, 'text': 'Цветочек полит! 💧'}`
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'nginx/1.18.0'), (b'Date', b'Thu, 16 Jan 2025 19:26:01 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'362'), (b'Connection', b'keep-alive'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Methods', b'GET, POST, OPTIONS'), (b'Access-Control-Expose-Headers', b'Content-Length,Content-Type,Date,Server,Connection')])
# INFO:httpx:HTTP Request: POST https://api.telegram.org/bot8034672081:AAF6O5a2wS1HSV5dVzDn2UeQuKbHL2kXGcM/getUpdates "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:telegram.ext.ExtBot:Call to Bot API endpoint `getUpdates` finished with return value `[{'update_id': 390207015, 'message': {'message_id': 506, 'from': {'id': 740990236, 'is_bot': False, 'first_name': 'moonsheep', 'username': 'moonsheep', 'language_code': 'ru'}, 'chat': {'id': 740990236, 'first_name': 'moonsheep', 'username': 'moonsheep', 'type': 'private'}, 'date': 1737055561, 'text': 'Удобрить 🌱'}}]`
# DEBUG:telegram.ext.ExtBot:Getting updates: [390207015]
# DEBUG:telegram.ext.Application:Processing update Update(message=Message(channel_chat_created=False, chat=Chat(first_name='moonsheep', id=740990236, type=<ChatType.PRIVATE>, username='moonsheep'), date=datetime.datetime(2025, 1, 16, 19, 26, 1, tzinfo=datetime.timezone.utc), delete_chat_photo=False, from_user=User(first_name='moonsheep', id=740990236, is_bot=False, language_code='ru', username='moonsheep'), group_chat_created=False, message_id=506, supergroup_chat_created=False, text='Удобрить 🌱'), update_id=390207015)
# DEBUG:telegram.ext.ExtBot:Calling Bot API endpoint `sendPhoto` with parameters `{'chat_id': 740990236, 'photo': <telegram._files.inputfile.InputFile object at 0x000001BC3C154340>, 'caption': 'Ура!🎉 Твой Цветок2 достиг стадии: Росточек! 🌸', 'reply_markup': ReplyKeyboardMarkup(keyboard=((KeyboardButton(text='Полить 💧'), KeyboardButton(text='Удобрить 🌱')), (KeyboardButton(text='Инвентарь 🏷️'), KeyboardButton(text='Новый цветочек🌺'))), resize_keyboard=True)}`
# DEBUG:telegram.ext.ExtBot:Calling Bot API endpoint `getUpdates` with parameters `{'timeout': 10, 'offset': 390207016}`
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'nginx/1.18.0'), (b'Date', b'Thu, 16 Jan 2025 19:26:01 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'1380'), (b'Connection', b'keep-alive'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Methods', b'GET, POST, OPTIONS'), (b'Access-Control-Expose-Headers', b'Content-Length,Content-Type,Date,Server,Connection')])
# INFO:httpx:HTTP Request: POST https://api.telegram.org/bot8034672081:AAF6O5a2wS1HSV5dVzDn2UeQuKbHL2kXGcM/sendPhoto "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:telegram.ext.ExtBot:Call to Bot API endpoint `sendPhoto` finished with return value `{'message_id': 507, 'from': {'id': 8034672081, 'is_bot': True, 'first_name': 'flower bot', 'username': 'haruhanabot'}, 'chat': {'id': 740990236, 'first_name': 'moonsheep', 'username': 'moonsheep', 'type': 'private'}, 'date': 1737055561, 'photo': [{'file_id': 'AgACAgIAAxkDAAIBlmeJTtyRQBXpMhoafKheO6MZQ7epAAIs7DEbqPZISLQ98p8AAcnr_wEAAwIAA3MAAzYE', 'file_unique_id': 'AQADLOwxG6j2SEh4', 'file_size': 853, 'width': 90, 'height': 90}, {'file_id': 'AgACAgIAAxkDAAIBlmeJTtyRQBXpMhoafKheO6MZQ7epAAIs7DEbqPZISLQ98p8AAcnr_wEAAwIAA20AAzYE', 'file_unique_id': 'AQADLOwxG6j2SEhy', 'file_size': 5089, 'width': 320, 'height': 320}, {'file_id': 'AgACAgIAAxkDAAIBlmeJTtyRQBXpMhoafKheO6MZQ7epAAIs7DEbqPZISLQ98p8AAcnr_wEAAwIAA3gAAzYE', 'file_unique_id': 'AQADLOwxG6j2SEh9', 'file_size': 16286, 'width': 800, 'height': 800}, {'file_id': 'AgACAgIAAxkDAAIBlmeJTtyRQBXpMhoafKheO6MZQ7epAAIs7DEbqPZISLQ98p8AAcnr_wEAAwIAA3kAAzYE', 'file_unique_id': 'AQADLOwxG6j2SEh-', 'file_size': 29526, 'width': 1280, 'height': 1280}, {'file_id': 'AgACAgIAAxkDAAIBlmeJTtyRQBXpMhoafKheO6MZQ7epAAIs7DEbqPZISLQ98p8AAcnr_wEAAwIAA3cAAzYE', 'file_unique_id': 'AQADLOwxG6j2SEh8', 'file_size': 55134, 'width': 2048, 'height': 2048}], 'caption': 'Ура!🎉 Твой Цветок2 достиг стадии: Росточек! 🌸'}`
# DEBUG:apscheduler.scheduler:Looking for jobs to run
# DEBUG:apscheduler.scheduler:Next wakeup is due at 2025-01-16 19:27:03.255858+00:00 (in 59.998042 seconds)
# INFO:apscheduler.executors.default:Running job "reminders (trigger: interval[0:01:00], next run at: 2025-01-16 19:27:03 UTC)" (scheduled at 2025-01-16 19:26:03.255858+00:00)
# DEBUG:telegram.ext.ExtBot:Calling Bot API endpoint `sendMessage` with parameters `{'chat_id': 740990236, 'text': 'Кажется, цветочек уже можно полить!;)'}`
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'nginx/1.18.0'), (b'Date', b'Thu, 16 Jan 2025 19:26:03 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'428'), (b'Connection', b'keep-alive'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Methods', b'GET, POST, OPTIONS'), (b'Access-Control-Expose-Headers', b'Content-Length,Content-Type,Date,Server,Connection')])
# INFO:httpx:HTTP Request: POST https://api.telegram.org/bot8034672081:AAF6O5a2wS1HSV5dVzDn2UeQuKbHL2kXGcM/sendMessage "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:telegram.ext.ExtBot:Call to Bot API endpoint `sendMessage` finished with return value `{'message_id': 508, 'from': {'id': 8034672081, 'is_bot': True, 'first_name': 'flower bot', 'username': 'haruhanabot'}, 'chat': {'id': 740990236, 'first_name': 'moonsheep', 'username': 'moonsheep', 'type': 'private'}, 'date': 1737055563, 'text': 'Кажется, цветочек уже можно полить!;)'}`
# DEBUG:telegram.ext.ExtBot:Calling Bot API endpoint `sendMessage` with parameters `{'chat_id': 740990236, 'text': 'Кажется, цветочек уже можно удобрить!;)'}`
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'nginx/1.18.0'), (b'Date', b'Thu, 16 Jan 2025 19:26:03 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'440'), (b'Connection', b'keep-alive'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Methods', b'GET, POST, OPTIONS'), (b'Access-Control-Expose-Headers', b'Content-Length,Content-Type,Date,Server,Connection')])
# INFO:httpx:HTTP Request: POST https://api.telegram.org/bot8034672081:AAF6O5a2wS1HSV5dVzDn2UeQuKbHL2kXGcM/sendMessage "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:telegram.ext.ExtBot:Call to Bot API endpoint `sendMessage` finished with return value `{'message_id': 509, 'from': {'id': 8034672081, 'is_bot': True, 'first_name': 'flower bot', 'username': 'haruhanabot'}, 'chat': {'id': 740990236, 'first_name': 'moonsheep', 'username': 'moonsheep', 'type': 'private'}, 'date': 1737055563, 'text': 'Кажется, цветочек уже можно удобрить!;)'}`
# INFO:apscheduler.executors.default:Job "reminders (trigger: interval[0:01:00], next run at: 2025-01-16 19:27:03 UTC)" executed successfully
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'nginx/1.18.0'), (b'Date', b'Thu, 16 Jan 2025 19:26:11 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'23'), (b'Connection', b'keep-alive'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Methods', b'GET, POST, OPTIONS'), (b'Access-Control-Expose-Headers', b'Content-Length,Content-Type,Date,Server,Connection')])
# INFO:httpx:HTTP Request: POST https://api.telegram.org/bot8034672081:AAF6O5a2wS1HSV5dVzDn2UeQuKbHL2kXGcM/getUpdates "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:telegram.ext.ExtBot:Call to Bot API endpoint `getUpdates` finished with return value `[]`
# DEBUG:telegram.ext.ExtBot:No new updates found.
# DEBUG:telegram.ext.ExtBot:Calling Bot API endpoint `getUpdates` with parameters `{'timeout': 10, 'offset': 390207016}`
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'nginx/1.18.0'), (b'Date', b'Thu, 16 Jan 2025 19:26:21 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'23'), (b'Connection', b'keep-alive'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Methods', b'GET, POST, OPTIONS'), (b'Access-Control-Expose-Headers', b'Content-Length,Content-Type,Date,Server,Connection')])
# INFO:httpx:HTTP Request: POST https://api.telegram.org/bot8034672081:AAF6O5a2wS1HSV5dVzDn2UeQuKbHL2kXGcM/getUpdates "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:telegram.ext.ExtBot:Call to Bot API endpoint `getUpdates` finished with return value `[]`
# DEBUG:telegram.ext.ExtBot:No new updates found.
# DEBUG:telegram.ext.ExtBot:Calling Bot API endpoint `getUpdates` with parameters `{'timeout': 10, 'offset': 390207016}`
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'nginx/1.18.0'), (b'Date', b'Thu, 16 Jan 2025 19:26:24 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'350'), (b'Connection', b'keep-alive'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Methods', b'GET, POST, OPTIONS'), (b'Access-Control-Expose-Headers', b'Content-Length,Content-Type,Date,Server,Connection')])
# INFO:httpx:HTTP Request: POST https://api.telegram.org/bot8034672081:AAF6O5a2wS1HSV5dVzDn2UeQuKbHL2kXGcM/getUpdates "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:telegram.ext.ExtBot:Call to Bot API endpoint `getUpdates` finished with return value `[{'update_id': 390207016, 'message': {'message_id': 510, 'from': {'id': 740990236, 'is_bot': False, 'first_name': 'moonsheep', 'username': 'moonsheep', 'language_code': 'ru'}, 'chat': {'id': 740990236, 'first_name': 'moonsheep', 'username': 'moonsheep', 'type': 'private'}, 'date': 1737055584, 'text': 'Полить 💧'}}]`
# DEBUG:telegram.ext.ExtBot:Getting updates: [390207016]
# ...
# INFO:httpx:HTTP Request: POST https://api.telegram.org/bot8034672081:AAF6O5a2wS1HSV5dVzDn2UeQuKbHL2kXGcM/getUpdates "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:telegram.ext.ExtBot:Call to Bot API endpoint `getUpdates` finished with return value `[]`
# DEBUG:telegram.ext.ExtBot:No new updates found.
# DEBUG:telegram.ext.ExtBot:Calling Bot API endpoint `getUpdates` with parameters `{'timeout': 10, 'offset': 390207046}`
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'nginx/1.18.0'), (b'Date', b'Thu, 16 Jan 2025 19:39:17 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'23'), (b'Connection', b'keep-alive'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Methods', b'GET, POST, OPTIONS'), (b'Access-Control-Expose-Headers', b'Content-Length,Content-Type,Date,Server,Connection')])
# INFO:httpx:HTTP Request: POST https://api.telegram.org/bot8034672081:AAF6O5a2wS1HSV5dVzDn2UeQuKbHL2kXGcM/getUpdates "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:telegram.ext.ExtBot:Call to Bot API endpoint `getUpdates` finished with return value `[]`
# DEBUG:telegram.ext.ExtBot:No new updates found.
# DEBUG:telegram.ext.ExtBot:Calling Bot API endpoint `getUpdates` with parameters `{'timeout': 10, 'offset': 390207046}`
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'nginx/1.18.0'), (b'Date', b'Thu, 16 Jan 2025 19:39:28 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'23'), (b'Connection', b'keep-alive'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Methods', b'GET, POST, OPTIONS'), (b'Access-Control-Expose-Headers', b'Content-Length,Content-Type,Date,Server,Connection')])
# INFO:httpx:HTTP Request: POST https://api.telegram.org/bot8034672081:AAF6O5a2wS1HSV5dVzDn2UeQuKbHL2kXGcM/getUpdates "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:telegram.ext.ExtBot:Call to Bot API endpoint `getUpdates` finished with return value `[]`
# DEBUG:telegram.ext.ExtBot:No new updates found.
# DEBUG:telegram.ext.ExtBot:Calling Bot API endpoint `getUpdates` with parameters `{'timeout': 10, 'offset': 390207046}`
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'nginx/1.18.0'), (b'Date', b'Thu, 16 Jan 2025 19:39:38 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'23'), (b'Connection', b'keep-alive'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Methods', b'GET, POST, OPTIONS'), (b'Access-Control-Expose-Headers', b'Content-Length,Content-Type,Date,Server,Connection')])
# INFO:httpx:HTTP Request: POST https://api.telegram.org/bot8034672081:AAF6O5a2wS1HSV5dVzDn2UeQuKbHL2kXGcM/getUpdates "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:telegram.ext.ExtBot:Call to Bot API endpoint `getUpdates` finished with return value `[]`
# DEBUG:telegram.ext.ExtBot:No new updates found.
# DEBUG:telegram.ext.ExtBot:Calling Bot API endpoint `getUpdates` with parameters `{'timeout': 10, 'offset': 390207046}`
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'nginx/1.18.0'), (b'Date', b'Thu, 16 Jan 2025 19:39:48 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'23'), (b'Connection', b'keep-alive'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Methods', b'GET, POST, OPTIONS'), (b'Access-Control-Expose-Headers', b'Content-Length,Content-Type,Date,Server,Connection')])
# INFO:httpx:HTTP Request: POST https://api.telegram.org/bot8034672081:AAF6O5a2wS1HSV5dVzDn2UeQuKbHL2kXGcM/getUpdates "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:telegram.ext.ExtBot:Call to Bot API endpoint `getUpdates` finished with return value `[]`
# DEBUG:telegram.ext.ExtBot:No new updates found.
# DEBUG:telegram.ext.ExtBot:Calling Bot API endpoint `getUpdates` with parameters `{'timeout': 10, 'offset': 390207046}`
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'nginx/1.18.0'), (b'Date', b'Thu, 16 Jan 2025 19:39:58 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'23'), (b'Connection', b'keep-alive'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Methods', b'GET, POST, OPTIONS'), (b'Access-Control-Expose-Headers', b'Content-Length,Content-Type,Date,Server,Connection')])
# INFO:httpx:HTTP Request: POST https://api.telegram.org/bot8034672081:AAF6O5a2wS1HSV5dVzDn2UeQuKbHL2kXGcM/getUpdates "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:telegram.ext.ExtBot:Call to Bot API endpoint `getUpdates` finished with return value `[]`
# DEBUG:telegram.ext.ExtBot:No new updates found.
# DEBUG:telegram.ext.ExtBot:Calling Bot API endpoint `getUpdates` with parameters `{'timeout': 10, 'offset': 390207046}`
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:telegram.ext.Application:Application received stop signal. Shutting down.
# DEBUG:telegram.ext.Updater:Stopping Updater
# DEBUG:telegram.ext.Updater:Waiting background polling task to finish up.
# DEBUG:telegram.ext.Updater:Network loop retry getting Updates was cancelled
# DEBUG:httpcore.http11:receive_response_headers.failed exception=CancelledError()
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:telegram.ext.Updater:Calling `get_updates` one more time to mark all fetched updates as read.
# DEBUG:telegram.ext.ExtBot:Calling Bot API endpoint `getUpdates` with parameters `{'timeout': 0, 'offset': 390207046}`
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:httpcore.connection:connect_tcp.started host='api.telegram.org' port=443 local_address=None timeout=5.0 socket_options=None
# DEBUG:apscheduler.scheduler:Looking for jobs to run
# DEBUG:apscheduler.scheduler:Next wakeup is due at 2025-01-16 19:41:03.255858+00:00 (in 59.975450 seconds)
# INFO:apscheduler.executors.default:Running job "reminders (trigger: interval[0:01:00], next run at: 2025-01-16 19:41:03 UTC)" (scheduled at 2025-01-16 19:40:03.255858+00:00)
# INFO:apscheduler.executors.default:Job "reminders (trigger: interval[0:01:00], next run at: 2025-01-16 19:41:03 UTC)" executed successfully
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x000001BC3BE95040>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x000001BC3C0A7A50> server_hostname='api.telegram.org' timeout=5.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x000001BC38ACA600>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'nginx/1.18.0'), (b'Date', b'Thu, 16 Jan 2025 19:40:03 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'23'), (b'Connection', b'keep-alive'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Methods', b'GET, POST, OPTIONS'), (b'Access-Control-Expose-Headers', b'Content-Length,Content-Type,Date,Server,Connection')])
# INFO:httpx:HTTP Request: POST https://api.telegram.org/bot8034672081:AAF6O5a2wS1HSV5dVzDn2UeQuKbHL2kXGcM/getUpdates "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:telegram.ext.ExtBot:Call to Bot API endpoint `getUpdates` finished with return value `[]`
# DEBUG:telegram.ext.ExtBot:No new updates found.
# DEBUG:telegram.ext.Updater:Updater.stop() is complete
# INFO:telegram.ext.Application:Application is stopping. This might take a moment.
# DEBUG:telegram.ext.Application:Waiting for update_queue to join
# DEBUG:telegram.ext.Application:Application stopped fetching of updates.
# DEBUG:telegram.ext.Application:Waiting for running jobs to finish
# INFO:apscheduler.scheduler:Scheduler has been shut down
# DEBUG:telegram.ext.Application:JobQueue stopped
# DEBUG:telegram.ext.Application:Waiting for `create_task` calls to be processed
# INFO:telegram.ext.Application:Application.stop() complete
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:close.complete
# DEBUG:telegram.ext.ExtBot:This Bot is already shut down. Returning.
# DEBUG:telegram.ext.Updater:Shut down of Updater complete
# DEBUG:telegram.ext.Application:This Application is already shut down. Returning.
# Бот остановлен.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[17], line 2
#       1 if __name__ == "__main__":
# ----> 2     asyncio.run(main())
#
# File ~\anaconda3\Lib\site-packages\nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File ~\anaconda3\Lib\site-packages\nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File ~\anaconda3\Lib\asyncio\futures.py:203, in Future.result(self)
#     201 self.__log_traceback = False
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# File ~\anaconda3\Lib\asyncio\tasks.py:314, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     310 try:
#     311     if exc is None:
#     312         # We use the `send` method directly, because coroutines
#     313         # don't have `__iter__` and `__next__` methods.
# --> 314         result = coro.send(None)
#     315     else:
#     316         result = coro.throw(exc)
#
# Cell In[16], line 19, in main()
#      17 try:
#      18     print("Бот запущен. Нажмите Ctrl+C для остановки.")
# ---> 19     await application.run_polling()
#      20 except KeyboardInterrupt:
#      21     print("Остановка бота...")
#
# File ~\anaconda3\Lib\site-packages\telegram\ext\_application.py:868, in Application.run_polling(self, poll_interval, timeout, bootstrap_retries, read_timeout, write_timeout, connect_timeout, pool_timeout, allowed_updates, drop_pending_updates, close_loop, stop_signals)
#     865 def error_callback(exc: TelegramError) -> None:
#     866     self.create_task(self.process_error(error=exc, update=None))
# --> 868 return self.__run(
#     869     updater_coroutine=self.updater.start_polling(
#     870         poll_interval=poll_interval,
#     871         timeout=timeout,
#     872         bootstrap_retries=bootstrap_retries,
#     873         read_timeout=read_timeout,
#     874         write_timeout=write_timeout,
#     875         connect_timeout=connect_timeout,
#     876         pool_timeout=pool_timeout,
#     877         allowed_updates=allowed_updates,
#     878         drop_pending_updates=drop_pending_updates,
#     879         error_callback=error_callback,  # if there is an error in fetching updates
#     880     ),
#     881     close_loop=close_loop,
#     882     stop_signals=stop_signals,
#     883 )
#
# File ~\anaconda3\Lib\site-packages\telegram\ext\_application.py:1099, in Application.__run(self, updater_coroutine, stop_signals, close_loop)
#    1097 finally:
#    1098     if close_loop:
# -> 1099         loop.close()
#
# File ~\anaconda3\Lib\asyncio\proactor_events.py:687, in BaseProactorEventLoop.close(self)
#     685 def close(self):
#     686     if self.is_running():
# --> 687         raise RuntimeError("Cannot close a running event loop")
#     688     if self.is_closed():
#     689         return
#
# RuntimeError: Cannot close a running event loop
